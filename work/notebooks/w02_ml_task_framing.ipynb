# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# *Classification*: Because we want to predict whether the page trend will be up , down or stable

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# I will predict a page's trend using a defined rule. If the page impression fails by a certain percentage then it goes down; if it's the opposite, it goes up; if it's the same, it's stable

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# Recoil because if we predict wrong, for example, we say it will rise, but it fails; the client loses opportunities and resources, or vice versa, and that is bad, and because i want the top-ranked pages to be mostly real opportunities, not false alarms.  we want to get as much accourcy as possible but the aim is around 85%

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# one row = one content page observation,
# built from a defined earlier feature window,
# and labeled by the later trend window.

# %%
# 1. Create a fast, temporary in-memory database connection
import duckdb
path = r"D:\Programing\flyrank-ml-internship-assignments\warehouse\fact_content_daily_performance\month=2026-01"
con = duckdb.connect(database=':memory:')
query_content = f"""
    SELECT   report_date , content_hash_id , gsc_impressions , gsc_clicks , gsc_sum_position
    FROM read_parquet('{path}/data_0.parquet')
    LIMIT 5
"""
print("--- Content Dimension Preview ---")
# .df() turns the SQL result directly into a Pandas DataFrame!
display(con.execute(query_content).df())
# Out:
# --- Content Dimension Preview ---
#   report_date           content_hash_id  gsc_impressions  gsc_clicks  \
# 0  2026-01-01  content_8c259838a3dfabe4               16           0
# 1  2026-01-01  content_5bbd1b5ea9f4d15c                1           0
# 2  2026-01-01  content_65b8a610174a1036               32           0
# 3  2026-01-01  content_3fc85bdef381af2d               79           0
# 4  2026-01-01  content_80071808216aef39             1041           0
#
#    gsc_sum_position
# 0                 8
# 1                 0
# 2               154
# 3               161
# 4              5844

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# there are to many factor for predicting if a page will lose impreison or not like the age older pages tend to be more stable than 6-7 month old pages, page tier that are in the top tend to reach a certen point then fail to many feature will be used so using if-statement will be not a good option

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
